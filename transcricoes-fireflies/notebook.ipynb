# %%
# Instalar as dependências necessárias
# %pip install boto3 requests fpdf python-dotenv

import boto3
import requests
from fpdf import FPDF
from datetime import datetime
from dotenv import load_dotenv
import os
# Out:
# Requirement already satisfied: boto3 in ./venv/lib/python3.10/site-packages (1.35.10)
# Requirement already satisfied: requests in ./venv/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: fpdf in ./venv/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: botocore<1.36.0,>=1.35.10 in ./venv/lib/python3.10/site-packages (from boto3) (1.35.10)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./venv/lib/python3.10/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./venv/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests) (3.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./venv/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.10->boto3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.10->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configurações
bucket_name = "transcricoes-fireflies-ttp"
url = "https://api.fireflies.ai/graphql"
fireflies_api_key = "467f3c6a-e4a7-4910-9500-34c302dfa15c"

s3 = boto3.client('s3')

def format_pdf(content, filename):
    try:
        pdf = FPDF()
        pdf.add_page()
        pdf.set_font("Arial", size=12)
        # Defina a largura da célula para a largura da página menos as margens
        page_width = pdf.w - 2 * pdf.l_margin
        previous_speaker = None
        
        for line in content.split('\n'):
            if previous_speaker and line.startswith(previous_speaker):
                # Se a linha começa com o nome do speaker anterior, remova o nome do speaker
                line = line[len(previous_speaker):].strip()
            elif ':' in line:
                # Se a linha contém ':', coloque o nome do speaker em negrito
                speaker, text = line.split(':', 1)
                pdf.set_font("Arial", style='B', size=12)
                pdf.multi_cell(page_width, 10, txt=speaker + ":", align='L')
                pdf.set_font("Arial", size=12)
                line = text.strip()
                previous_speaker = speaker
            pdf.multi_cell(page_width, 10, txt=line, align='L')
        
        pdf_output = f"/tmp/{filename}"
        pdf.output(pdf_output)
        return pdf_output
    except Exception as e:
        print(f"Erro ao criar PDF: {e}")
        raise

def format_date(date_string):
    try:
        # Converter a string para um objeto datetime
        date_object = datetime.strptime(date_string, "%Y-%m-%dT%H:%M:%S.%fZ")
        formatted_date = date_object.strftime("%d-%m-%Y")
        return formatted_date
    except Exception as e:
        print(f"Erro ao formatar data: {e}")
        raise

try:
    payload = "{\"query\":\"query Transcripts($fromDate: DateTime) { transcripts(fromDate: $fromDate) { title id dateString sentences { index speaker_name text } } }\",\"variables\":{\"fromDate\":\"2024-09-04T17:13:46.660Z\"}}"
    headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer 467f3c6a-e4a7-4910-9500-34c302dfa15c'
    }

    response = requests.request("POST", url, headers=headers, data=payload, verify=False)

    # Verificar se a requisição foi bem-sucedida
    if response.status_code == 200:
        data = json.loads(response.text)

        for item in data['data']["transcripts"]:
            formatted_date = format_date(item['dateString'])

            # Gerar o conteúdo do PDF
            pdf_content = f"{item['title']} - {formatted_date}\n\n"
            previous_speaker = ""
            if item['sentences']:
                for sentence in item['sentences']:
                    if previous_speaker: 
                        if sentence['speaker_name'] == previous_speaker:
                            pdf_content = pdf_content.rstrip('\n') + f" {sentence['text']}\n"
                        else:
                            pdf_content += f"{sentence['speaker_name']}: {sentence['text']}\n"
                    previous_speaker = sentence['speaker_name']
                    
            # Criar o PDF
            pdf_filename = f"{item['id']}.pdf"
            pdf_path = format_pdf(pdf_content, pdf_filename)

            # Salvar o PDF no S3
            with open(pdf_path, "rb") as pdf_file:
                s3.put_object(Bucket=bucket_name, Key=pdf_filename, Body=pdf_file)

            print('PDF salvo no S3', pdf_filename)
    else:
        print('Falha na requisição para o Fireflies.')
except requests.exceptions.RequestException as e:
    print(f"Erro na requisição: {e}")
except Exception as e:
    print(f"Erro geral: {e}")
# Out:
# Requirement already satisfied: boto3 in ./venv/lib/python3.10/site-packages (1.35.10)
# Requirement already satisfied: requests in ./venv/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: fpdf in ./venv/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: botocore<1.36.0,>=1.35.10 in ./venv/lib/python3.10/site-packages (from boto3) (1.35.10)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./venv/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./venv/lib/python3.10/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./venv/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.10->boto3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.10->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# /home/palomapatriciafalchi/Documentos/repositorios/lambda-s3/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.fireflies.ai'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# data['data']['transcripts'] [{'title': 'PlayZup: Bate Papo Inicial (Andre Junior)', 'id': 'a76Zg0Tq2N9RzcbN', 'dateString': '2024-09-04T18:28:07.178Z', 'sentences': [{'index': 0, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'E aí.'}, {'index': 1, 'speaker_name': 'Andre Junior', 'text': 'Boa tarde.'}, {'index': 2, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Oi, André.'}, {'index': 3, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Boa tarde.'}, {'index': 4, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Tudo bem?'}, {'index': 5, 'speaker_name': 'Andre Junior', 'text': 'Bom, você?'}, {'index': 6, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Só pelo tempo, gentileza.'}, {'index': 7, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Tudo bem por aqui.'}, {'index': 8, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então vamos lá, André.'}, {'index': 9, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Boa tarde.'}, {'index': 10, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Seja bem-vindo aqui ao nosso papo.'}, {'index': 11, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Você fala de São Paulo?'}, {'index': 12, 'speaker_name': 'Andre Junior', 'text': 'Boa tarde.'}, {'index': 13, 'speaker_name': 'Andre Junior', 'text': 'Osasco.'}, {'index': 14, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Osasco, né?'}, {'index': 15, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Muito bom.'}, {'index': 16, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Está pertinho de São Paulo.'}, {'index': 17, 'speaker_name': 'Andre Junior', 'text': 'É.'}, {'index': 18, 'speaker_name': 'Andre Junior', 'text': 'Exatamente.'}, {'index': 19, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'É.'}, {'index': 20, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Me conta sobre a Azul, que você já nos conhece, a sua primeira experiência.'}, {'index': 21, 'speaker_name': 'Andre Junior', 'text': 'A primeira experiência, eu já ouvi falar.'}, {'index': 22, 'speaker_name': 'Andre Junior', 'text': 'Meu pai trabalhou junto com a Zupi em uma empresa que ele fazia parte.'}, {'index': 23, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Como assim?'}, {'index': 24, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Quem é seu pai?'}, {'index': 25, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Aqueles?'}, {'index': 26, 'speaker_name': 'Andre Junior', 'text': 'É uma...'}, {'index': 27, 'speaker_name': 'Andre Junior', 'text': 'isso que não vai conhecer.'}, {'index': 28, 'speaker_name': 'Andre Junior', 'text': 'Ele trabalhou em conjunto com uma outra empresa.'}, {'index': 29, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Mas ele estava em qual empresa?'}, {'index': 30, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Só para eu entender o rolê aqui.'}, {'index': 31, 'speaker_name': 'Andre Junior', 'text': 'Esqueci o nome, na verdade.'}, {'index': 32, 'speaker_name': 'Andre Junior', 'text': 'Ah, tá.'}, {'index': 33, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então vamos lá, aqui nesse papo nós vamos alinhar com relação, além de te conhecer um pouquinho da estratégia que a Azup vem trabalhando agora e ali para o final a gente fala a respeito de remuneração, tá bom?'}, {'index': 34, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Gostaria de ouvir um pouquinho sobre o André para além da experiência profissional Quem é você, o que você gosta, por que você está aqui nesse papo com a gente?'}, {'index': 35, 'speaker_name': 'Andre Junior', 'text': 'Bom, eu sou o André, tenho 20 anos.'}, {'index': 36, 'speaker_name': 'Andre Junior', 'text': 'Hoje eu faço faculdade em inteligência artificial na FIAP.'}, {'index': 37, 'speaker_name': 'Andre Junior', 'tex ...
# {'title': 'PlayZup: Bate Papo Inicial (Andre Junior)', 'id': 'a76Zg0Tq2N9RzcbN', 'dateString': '2024-09-04T18:28:07.178Z', 'sentences': [{'index': 0, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'E aí.'}, {'index': 1, 'speaker_name': 'Andre Junior', 'text': 'Boa tarde.'}, {'index': 2, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Oi, André.'}, {'index': 3, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Boa tarde.'}, {'index': 4, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Tudo bem?'}, {'index': 5, 'speaker_name': 'Andre Junior', 'text': 'Bom, você?'}, {'index': 6, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Só pelo tempo, gentileza.'}, {'index': 7, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Tudo bem por aqui.'}, {'index': 8, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então vamos lá, André.'}, {'index': 9, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Boa tarde.'}, {'index': 10, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Seja bem-vindo aqui ao nosso papo.'}, {'index': 11, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Você fala de São Paulo?'}, {'index': 12, 'speaker_name': 'Andre Junior', 'text': 'Boa tarde.'}, {'index': 13, 'speaker_name': 'Andre Junior', 'text': 'Osasco.'}, {'index': 14, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Osasco, né?'}, {'index': 15, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Muito bom.'}, {'index': 16, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Está pertinho de São Paulo.'}, {'index': 17, 'speaker_name': 'Andre Junior', 'text': 'É.'}, {'index': 18, 'speaker_name': 'Andre Junior', 'text': 'Exatamente.'}, {'index': 19, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'É.'}, {'index': 20, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Me conta sobre a Azul, que você já nos conhece, a sua primeira experiência.'}, {'index': 21, 'speaker_name': 'Andre Junior', 'text': 'A primeira experiência, eu já ouvi falar.'}, {'index': 22, 'speaker_name': 'Andre Junior', 'text': 'Meu pai trabalhou junto com a Zupi em uma empresa que ele fazia parte.'}, {'index': 23, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Como assim?'}, {'index': 24, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Quem é seu pai?'}, {'index': 25, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Aqueles?'}, {'index': 26, 'speaker_name': 'Andre Junior', 'text': 'É uma...'}, {'index': 27, 'speaker_name': 'Andre Junior', 'text': 'isso que não vai conhecer.'}, {'index': 28, 'speaker_name': 'Andre Junior', 'text': 'Ele trabalhou em conjunto com uma outra empresa.'}, {'index': 29, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Mas ele estava em qual empresa?'}, {'index': 30, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Só para eu entender o rolê aqui.'}, {'index': 31, 'speaker_name': 'Andre Junior', 'text': 'Esqueci o nome, na verdade.'}, {'index': 32, 'speaker_name': 'Andre Junior', 'text': 'Ah, tá.'}, {'index': 33, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então vamos lá, aqui nesse papo nós vamos alinhar com relação, além de te conhecer um pouquinho da estratégia que a Azup vem trabalhando agora e ali para o final a gente fala a respeito de remuneração, tá bom?'}, {'index': 34, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Gostaria de ouvir um pouquinho sobre o André para além da experiência profissional Quem é você, o que você gosta, por que você está aqui nesse papo com a gente?'}, {'index': 35, 'speaker_name': 'Andre Junior', 'text': 'Bom, eu sou o André, tenho 20 anos.'}, {'index': 36, 'speaker_name': 'Andre Junior', 'text': 'Hoje eu faço faculdade em inteligência artificial na FIAP.'}, {'index': 37, 'speaker_name': 'Andre Junior', 'text': 'Eu gosto de videogame, a ...
# TEM SENTENCE
# sentence {'index': 0, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'E aí.'}
# previous_speaker
# sentence {'index': 1, 'speaker_name': 'Andre Junior', 'text': 'Boa tarde.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 2, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Oi, André.'}
# previous_speaker Andre Junior
# sentence {'index': 3, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Boa tarde.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 4, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Tudo bem?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 5, 'speaker_name': 'Andre Junior', 'text': 'Bom, você?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 6, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Só pelo tempo, gentileza.'}
# previous_speaker Andre Junior
# sentence {'index': 7, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Tudo bem por aqui.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 8, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então vamos lá, André.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 9, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Boa tarde.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 10, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Seja bem-vindo aqui ao nosso papo.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 11, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Você fala de São Paulo?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 12, 'speaker_name': 'Andre Junior', 'text': 'Boa tarde.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 13, 'speaker_name': 'Andre Junior', 'text': 'Osasco.'}
# previous_speaker Andre Junior
# sentence {'index': 14, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Osasco, né?'}
# previous_speaker Andre Junior
# sentence {'index': 15, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Muito bom.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 16, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Está pertinho de São Paulo.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 17, 'speaker_name': 'Andre Junior', 'text': 'É.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 18, 'speaker_name': 'Andre Junior', 'text': 'Exatamente.'}
# previous_speaker Andre Junior
# sentence {'index': 19, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'É.'}
# previous_speaker Andre Junior
# sentence {'index': 20, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Me conta sobre a Azul, que você já nos conhece, a sua primeira experiência.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 21, 'speaker_name': 'Andre Junior', 'text': 'A primeira experiência, eu já ouvi falar.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 22, 'speaker_name': 'Andre Junior', 'text': 'Meu pai trabalhou junto com a Zupi em uma empresa que ele fazia parte.'}
# previous_speaker Andre Junior
# sentence {'index': 23, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Como assim?'}
# previous_speaker Andre Junior
# sentence {'index': 24, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Quem é seu pai?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 25, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Aqueles?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 26, 'speaker_name': 'Andre Junior', 'text': 'É uma...'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 27, 'speaker_name': 'Andre Junior', 'text': 'isso que não vai conhecer.'}
# previous_speaker Andre Junior
# sentence {'index': 28, 'speaker_name': 'Andre Junior', 'text': 'Ele trabalhou em conjunto com uma outra empresa.'}
# previous_speaker Andre Junior
# sentence {'index': 29, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Mas ele estava em qual empresa?'}
# previous_speaker Andre Junior
# sentence {'index': 30, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Só para eu entender o rolê aqui.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 31, 'speaker_name': 'Andre Junior', 'text': 'Esqueci o nome, na verdade.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 32, 'speaker_name': 'Andre Junior', 'text': 'Ah, tá.'}
# previous_speaker Andre Junior
# sentence {'index': 33, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então vamos lá, aqui nesse papo nós vamos alinhar com relação, além de te conhecer um pouquinho da estratégia que a Azup vem trabalhando agora e ali para o final a gente fala a respeito de remuneração, tá bom?'}
# previous_speaker Andre Junior
# sentence {'index': 34, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Gostaria de ouvir um pouquinho sobre o André para além da experiência profissional Quem é você, o que você gosta, por que você está aqui nesse papo com a gente?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 35, 'speaker_name': 'Andre Junior', 'text': 'Bom, eu sou o André, tenho 20 anos.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 36, 'speaker_name': 'Andre Junior', 'text': 'Hoje eu faço faculdade em inteligência artificial na FIAP.'}
# previous_speaker Andre Junior
# sentence {'index': 37, 'speaker_name': 'Andre Junior', 'text': 'Eu gosto de videogame, anime, ler.'}
# previous_speaker Andre Junior
# sentence {'index': 38, 'speaker_name': 'Andre Junior', 'text': 'Gosto de aprender.'}
# previous_speaker Andre Junior
# sentence {'index': 39, 'speaker_name': 'Andre Junior', 'text': 'Eu me interessei pela ZOOP, principalmente por causa da inteligência artificial, que é nova.'}
# previous_speaker Andre Junior
# sentence {'index': 40, 'speaker_name': 'Andre Junior', 'text': 'Porque eu gosto, assim, de aprender mesmo.'}
# previous_speaker Andre Junior
# sentence {'index': 41, 'speaker_name': 'Andre Junior', 'text': 'E...'}
# previous_speaker Andre Junior
# sentence {'index': 42, 'speaker_name': 'Andre Junior', 'text': 'Ah, é isso mesmo.'}
# previous_speaker Andre Junior
# sentence {'index': 43, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Boa.'}
# previous_speaker Andre Junior
# sentence {'index': 44, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Agora a gente vai falar um pouquinho sobre a parte técnica.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 45, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Esse momento é seu, então eu dividi aqui em camadas e entender um pouquinho ali de quais tecnologias que você mais tem experiência, tá?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 46, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então você vai falando ali a camada Exemplo, linguagem de programação, engenharia de dados, o que você utiliza?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 47, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'coleta de dados, né, setup, quais as tecnologias ali que você mais tem domínio.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 48, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'E aí você pode estruturar não só na parte on-premise, mas também se já utilizou cloud, quais os serviços da cloud ali.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 49, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então fica super à vontade.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 50, 'speaker_name': 'Andre Junior', 'text': 'Eu tenho três anos de experiência como engenheiro de dados.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 51, 'speaker_name': 'Andre Junior', 'text': 'Eu tenho experiência em Python, R, SQL, coleta de dados, tem experiência com a AWS, mais com a AWS.'}
# previous_speaker Andre Junior
# sentence {'index': 52, 'speaker_name': 'Andre Junior', 'text': 'Agora a AWS, S2, S3, Glue, Athena, Datamesh, só a CloudWs que eu uso mais.'}
# previous_speaker Andre Junior
# sentence {'index': 53, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Durante esses três anos de experiência com engenharia de dados Qual foi o projeto mais relevante?'}
# previous_speaker Andre Junior
# sentence {'index': 54, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Como foi sua participação durante a entrega?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 55, 'speaker_name': 'Andre Junior', 'text': 'Conta um pouquinho para nós Eu fui freelancer em uma empresa de consultoria junto com o meu pai, essa consultoria prestava serviço para outra consultoria, que prestou consultoria em um projeto para a Secretaria do Rio Grande do Sul.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 56, 'speaker_name': 'Andre Junior', 'text': 'Lá a gente usava o AWS e lá a gente criava pipeline de dados, usava o S3.'}
# previous_speaker Andre Junior
# sentence {'index': 57, 'speaker_name': 'Andre Junior', 'text': 'Por exemplo, usava o CSV, que transferia esses arquivos para Python, que transferia de novo para S3.'}
# previous_speaker Andre Junior
# sentence {'index': 58, 'speaker_name': 'Andre Junior', 'text': 'que levava até o Atina para ser criado esses dados, que levava até o Glue, que fazia a inflação desse arquivo no Glue, que fazia uma trigger, um tempo estimulado de hora em hora e segundo em segundo para ver esses dados.'}
# previous_speaker Andre Junior
# sentence {'index': 59, 'speaker_name': 'Andre Junior', 'text': 'E às vezes usava o EC2 para também fazer essas leituras de dado e elevar esses dados transformados até um S3 que virar um arquivo parquet.'}
# previous_speaker Andre Junior
# sentence {'index': 60, 'speaker_name': 'Andre Junior', 'text': 'Boa.'}
# previous_speaker Andre Junior
# sentence {'index': 61, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'E aí, durante essa jornada, você foi mais aqui nessas principais etapas de ETL, de coleta, processamento, chegou a trabalhar com as outras demais ou não?'}
# previous_speaker Andre Junior
# sentence {'index': 62, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Ou o time era mais multidisciplinar e aí tinha outras pessoas responsáveis?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 63, 'speaker_name': 'Andre Junior', 'text': 'É outras pessoas responsáveis.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 64, 'speaker_name': 'Andre Junior', 'text': 'Boa.'}
# previous_speaker Andre Junior
# sentence {'index': 65, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Vou falar um pouquinho aqui a respeito da Azup.'}
# previous_speaker Andre Junior
# sentence {'index': 66, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'A Azup faz parte do grupo Itaú desde 2019.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 67, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Nós temos o banco ali como nosso principal cliente e, além disso, a Azup passa a se posicionar como uma empresa de produto, na qual a gente tem três soluções ali, da StackSpot quanto AI, StackSpot Cloud e também EDP como plataforma interna de desenvolvimento.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 68, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'A 15-unit são outras unidades de negócios que esses clientes parceiros, eles se conectam com uma destas soluções da Stackspot, e a consequência dessa parceria é um time de professional service que a Azup estrutura, para que a gente consiga implementar ali no ambiente do cliente.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 69, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'A Azup hoje, dentro da estratégia de dados, ela é 100% voltada para o Itaú, dentro do Itaú, por ter uma volumetria de dados muito significativa, a gente tem ali uma estratégia de tração profissionais de dados, não só da engenharia, mas na parte de ciência, análise, machine learning, para contextos específicos de negócios, potencializando essa cultura de data mesh.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 70, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então, hoje, o nosso processo tem uma expectativa de mais três etapas para que a gente consiga entender mais detalhes, com profundidade, o seu perfil técnico e entender qual estrutura do Itaú a gente te apresentaria para que pudesse entender a viabilidade e a jornada no todo.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 71, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então a gente tem ali o próximo etapa, a gente fala de cultura depois a gente entende um pouquinho na parte técnica com um especialista técnico que vai aprofundar a respeito das tecnologias e também a última etapa seria um bate-papo de gestão que na verdade é um bate-papo ali para você conhecer do desafio em si, ok?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 72, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'A ZUP tem 14 anos de empresa, é uma empresa extremamente competente e vem trabalhando de uma forma muito exponencial no seu crescimento de negócio, na evolução das pessoas.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 73, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Nós iniciamos uma outra jornada de expansão da StackSpot para os Estados Unidos no ano passado e essa estratégia já está há 12 meses e já temos a conversão ali de um cliente principal na iniciativa do Alexandre Mandel, que é um dos executivos que vem trabalhando esse projeto ali em Nova Iorque, tá?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 74, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Mas, em resumo, a ZUP é isso.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 75, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Hoje nós temos 3 mil ZUPers espalhados em mais de 400 cidades no Brasil, graças ao nosso programa aí de liberdade.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 76, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Dúvidas sobre a parte aqui de negócios?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 77, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Algo mais sobre a ZUP?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 78, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'The Unit é a nossa terceira unidade de negócios, onde a gente concentra os clientes que são diferentes do segmento financeiro, que seria o principal ali, enquanto Itaú.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 79, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então, além da Localiza, Rede, Vivo, Porto Seguro, a gente tem também ali com a Creditas, uma parceria com a Núclea de São Paulo, é onde a gente concentra essa parceria de demais clientes.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 80, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então, são três frentes, principais.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 81, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Cliente Itaú como o principal e o maior, tem a parte de estrutura da StackSpot e o Unity ali com os outros clientes.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 82, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Entendi.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 83, 'speaker_name': 'Andre Junior', 'text': 'Interessante.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 84, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Falando um pouquinho, hoje as nossas contratações elas acontecem no regime CLT, de forma exclusiva, isso significa que paralelo ao contrato da ZUP, eu não tenho, eu não consigo, de fato, evoluir em outras prestações de serviços ali, em outras instituições, financeiramente falando.'}
# previous_speaker Andre Junior
# sentence {'index': 85, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Isso aqui seria um impeditivo para você hoje?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 86, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Nossos prazos de admissões vão de 10 a 30 dias, e aí depende muito ali do momento em que você recebe alguma proposta da Azul, que a gente seta a expectativa de uma data fixa para começo.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 87, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Sobre remuneração, o que você tem de pretensão de salário?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 88, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Como tem sido suas últimas contratações referente à atuação?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 89, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Você falou que atuou em uma consultoria, foi CLT, foi PJ...'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 90, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'PJ?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 91, 'speaker_name': 'Andre Junior', 'text': 'Era 5 mil.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 92, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': '5 mil e você estava como júnior?'}
# previous_speaker Andre Junior
# sentence {'index': 93, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Beleza, eu acho que tá super dentro ali do que a gente vem praticando, claro que isso pode influenciar para mais ou para menos, depois de uma entrevista técnica, né, que a gente entende ali a profundidade do perfil Então, no mais, é isso.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 94, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Nosso papo foi super rápido, então geralmente esse primeiro papo é mais para alinhar, te passar um pouquinho sobre essas informações.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 95, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Eu vou precisar...'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 96, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'A gente conversou pelo WhatsApp, né, André?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 97, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Eu vou te passar lá um complemento do nosso papo, que é um arquivo ali com a nossa lista de benefícios, e também o link da próxima agenda, que a gente conversa sobre cultura, tá bom?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 98, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Que aí você escolhe o melhor dia e horário para a gente evoluir.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 99, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Beleza?'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 100, 'speaker_name': 'Andre Junior', 'text': 'Beleza.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 101, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Então é isso, bem-vindo ao nosso processo, uma ótima quarta-feira aí, um final de tarde para você.'}
# previous_speaker Andre Junior
# sentence {'index': 102, 'speaker_name': 'Andre Junior', 'text': 'Obrigado, bom trabalho.'}
# previous_speaker Leandro Alves - Talent Acquisition
# sentence {'index': 103, 'speaker_name': 'Leandro Alves - Talent Acquisition', 'text': 'Obrigado, até mais, tchau, tchau.'}
# previous_speaker Andre Junior
# PDF salvo no S3 a76Zg0Tq2N9RzcbN.pdf
# {'title': 'Hora da entrevista técnica! | Zup e Rafael', 'id': 'H9kWT9LmJltZmsJl', 'dateString': '2024-09-04T17:58:08.548Z', 'sentences': [{'index': 0, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Do Jogo Antigo?'}, {'index': 1, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Sim.'}, {'index': 2, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Você?'}, {'index': 3, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Sim, também.'}, {'index': 4, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Ótimo.'}, {'index': 5, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Bacana.'}, {'index': 6, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Aqui você já teve um contato com uma pessoa da ZOOP antes, né?'}, {'index': 7, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Fez o seu processo e aí veio para a entrevista que foi a...'}, {'index': 8, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'quem foi?'}, {'index': 9, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Vanessa, se eu não me engano.'}, {'index': 10, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Vanessa, perfeito.'}, {'index': 11, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Aí ela já fez uma entrevista prévia, né, de FIT Cultural?'}, {'index': 12, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Sim.'}, {'index': 13, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Perfeito.'}, {'index': 14, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Aqui, eu sou gestor da área aqui, né?'}, {'index': 15, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Algumas equipes aqui, atronalho de indicação e estamos com algumas vagas ali, né?'}, {'index': 16, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Temos vagas para especialistas e líder técnico, né?'}, {'index': 17, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Eu vi que o seu perfil ali, ele bate um pouco com um dos dois, né?'}, {'index': 18, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Eu não sei, é um pouco disso, né?'}, {'index': 19, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Especialista e líder técnico participando.'}, {'index': 20, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Quer um bate-papo pra gente?'}, {'index': 21, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'se conhecer mesmo, né?'}, {'index': 22, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'E depois a gente fazer alguns testezinhos ali para a gente fazer...'}, {'index': 23, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Basicamente é um processo de avaliação que a gente tem, né?'}, {'index': 24, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Agora, aliás, tem que dar a surpresa.'}, {'index': 25, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Tudo bem.'}, {'index': 26, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'O meu nome é Daniel, né?'}, {'index': 27, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Eu sou gestor aqui da área.'}, {'index': 28, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Eu estou com duas squads aqui que trabalham em produtos de autenticação interna para o Itaú, né?'}, {'index': 29, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Que a gente já está usando para o Itaú, construindo um...'}, {'index': 30, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'um SDK e uma série de componentes back-end que garantem ali os processos de autenticação dos produtos do Itaú, que a gente embebe esse produto em parceiros, né?'}, {'index': 31, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Então é o SDK que vai no parceiro ali, consumindo os serviços do Itaú.'}, {'index': 32, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'E o parceiro, hoje, é porte-seguro, tá em shopping, né?'}, {'index': 33, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Então a gente constrói esse componente de se ...
# TEM SENTENCE
# sentence {'index': 0, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Do Jogo Antigo?'}
# previous_speaker
# sentence {'index': 1, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Sim.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 2, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Você?'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 3, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Sim, também.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 4, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Ótimo.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 5, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Bacana.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 6, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Aqui você já teve um contato com uma pessoa da ZOOP antes, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 7, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Fez o seu processo e aí veio para a entrevista que foi a...'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 8, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'quem foi?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 9, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Vanessa, se eu não me engano.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 10, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Vanessa, perfeito.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 11, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Aí ela já fez uma entrevista prévia, né, de FIT Cultural?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 12, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Sim.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 13, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Perfeito.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 14, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Aqui, eu sou gestor da área aqui, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 15, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Algumas equipes aqui, atronalho de indicação e estamos com algumas vagas ali, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 16, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Temos vagas para especialistas e líder técnico, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 17, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Eu vi que o seu perfil ali, ele bate um pouco com um dos dois, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 18, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Eu não sei, é um pouco disso, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 19, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Especialista e líder técnico participando.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 20, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Quer um bate-papo pra gente?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 21, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'se conhecer mesmo, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 22, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'E depois a gente fazer alguns testezinhos ali para a gente fazer...'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 23, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Basicamente é um processo de avaliação que a gente tem, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 24, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Agora, aliás, tem que dar a surpresa.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 25, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Tudo bem.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 26, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'O meu nome é Daniel, né?'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 27, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Eu sou gestor aqui da área.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 28, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Eu estou com duas squads aqui que trabalham em produtos de autenticação interna para o Itaú, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 29, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Que a gente já está usando para o Itaú, construindo um...'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 30, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'um SDK e uma série de componentes back-end que garantem ali os processos de autenticação dos produtos do Itaú, que a gente embebe esse produto em parceiros, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 31, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Então é o SDK que vai no parceiro ali, consumindo os serviços do Itaú.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 32, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'E o parceiro, hoje, é porte-seguro, tá em shopping, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 33, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Então a gente constrói esse componente de segurança para viabilizar as operações bancárias no aplicativo do parceiro ali.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 34, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'A gente faz parte de uma...'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 35, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'uma estrutura aqui de autenticação, onde nós somos duas squads aqui e tem mais umas dez squads ali que atuam, por exemplo, no Super App, no FPJ, atuam em Parts Score, em biometria, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 36, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Então, tem várias squads ali que formam a release train de autenticação do banco, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 37, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Então, essa é mais ou menos a estrutura que você iria participar ali, tá?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 38, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'As squads que a gente tem ali e do que a gente vai trabalhar, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 39, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Então, a VIA é basicamente Java, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 40, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'A gente tem um serviço ali do fornecedor, o Team Federation, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 41, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Que fornece um serviço de geração de token, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 42, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Então, é uma plataforma ali que implementa o OAuth, os fluxos de autorização, e personaliza ali para o Itaú.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 43, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'E os serviços, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 44, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'A gente tem mesmo os credenciais, os serviços que suportam isso aí, rodam basicamente ali na AWS.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 45, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Tentar dar um panorama, mais ou menos, do que a gente trabalha aqui, tá?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 46, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Se tiver alguma dúvida.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 47, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Mas aí eu ia pedir pra você se apresentar, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 48, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'E contar um pouquinho da sua história aí.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 49, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Certo.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 50, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Você começou por TI, né?'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 51, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Começou a trabalhar ali até hoje, mais ou menos.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 52, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Por uma resumida, né?'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 53, 'speaker_name': 'Daniel Rodrigo Dettmer Dorta', 'text': 'Mas tentar passar um pouquinho da sua história.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 54, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Certo.'}
# previous_speaker Daniel Rodrigo Dettmer Dorta
# sentence {'index': 55, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Eu tenho 37 anos.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 56, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Eu moro aqui na região metropolitana de Fortaleza, Caucá e Ceará.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 57, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Eu tô em TI, estudando e trabalhando desde os 17, 16 anos.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 58, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Eu comecei mais cedo, mas não conto muito, porque foi um curso de webdesign, mas eu comecei na área de suporte, e lá para os 19 anos eu programei em assembly, com a minha controladora, construí alguns circuitos e tal, estagiei na área, e a área de programação me chamou atenção.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 59, 'speaker_name': 'Rafael Alves Silveira', 'text': 'E, aos 20, fui na faculdade e, de seis meses a um ano, eu tava trabalhando já.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 60, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Acho que um ano e meio eu já tava contratado.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 61, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Nascerense, mas era um VB, né?'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 62, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Então, VB6.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 63, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Eu nunca tinha visto nada de VB6.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 64, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Mas deu certo, em dois meses eu entreguei um software.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 65, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Esse tinha um software integrado com umas câmeras de portaria e outros sistemas para levar esses dados da entrada.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 66, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Então fiquei lá um tempo, mas aí eu queria ir para a área de Java ou da Internet, um dos dois.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 67, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Era o que estava na época bombando e eu não queria ficar...'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 68, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Era um programador aos 21 anos de VB6.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 69, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Então, então eu peguei algumas coisas e vi o Bnet, mas era muito pouco, era tipo integração de pistola, alguma coisa assim, de leitor, de leitor de código de baixo, tipo de coisa.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 70, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Então, o internário de Java em si, acho que com 21.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 71, 'speaker_name': 'Rafael Alves Silveira', 'text': 'E até hoje, 90% do meu trabalho foi com ambiente Java.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 72, 'speaker_name': 'Rafael Alves Silveira', 'text': 'Às vezes com frameworks padrão, tipo JTSF, PrimeFaces.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 73, 'speaker_name': 'Rafael Alves Silveira', 'text': 'E depois, posteriormente, com Angular e AngularJS, coisas que eu já trabalhei de frontend.'}
# previous_speaker Rafael Alves Silveira
# sentence {'index': 74, 'speaker_name': 'Rafael Alves Silveira', 'text': 'O primeiro projeto que eu peguei era em Spring, não tinha Spring Boot ainda, depois mais pra frente que eu peguei Spring Boot, mas eu sempre peguei Legado e migrei para Microservices em Java.'}
# previous_speaker Rafael Alves Silveira
# ...
# previous_speaker Felipe Garcia
# sentence {'index': 485, 'speaker_name': 'Felipe Garcia', 'text': 'A gente tem um monte de coisas relacionadas aí.'}
# previous_speaker Felipe Garcia
# sentence {'index': 486, 'speaker_name': 'Felipe Garcia', 'text': 'Então, acho que o que difere bastante das Big Techs é que, assim, nas Big Techs, apesar de você ter muita autonomia, muita pista para fazer as coisas, boa parte desses processos fundamentais meio que já tem uma mega estrutura por trás, tem muita coisa que vem top down, que algum gringo cria e o mundo inteiro faz.'}
# previous_speaker Felipe Garcia
# sentence {'index': 487, 'speaker_name': 'Felipe Garcia', 'text': 'Tem a oportunidade de você começar na tua região e exportar também, mas são coisas mais tropicalizadas.'}
# previous_speaker Felipe Garcia
# sentence {'index': 488, 'speaker_name': 'Felipe Garcia', 'text': 'Mas aqui na ZUP, é muito aberto e depende de cada time, cada célula tomar iniciativa e começar a fazer os processos, porque a gente não tem essa estrutura corporativa que está olhando para o todo e vai analisar número que está funcionando, que não está, pegar feedback e criar processo.'}
# previous_speaker Felipe Garcia
# sentence {'index': 489, 'speaker_name': 'Felipe Garcia', 'text': 'Então depende muito da gente.'}
# previous_speaker Felipe Garcia
# sentence {'index': 490, 'speaker_name': 'Felipe Garcia', 'text': 'Então acho que essas daí são as principais semelhanças e diferenças com as Big Techs.'}
# previous_speaker Felipe Garcia
# sentence {'index': 491, 'speaker_name': 'André Heitor', 'text': 'Interessante.'}
# previous_speaker Felipe Garcia
# sentence {'index': 492, 'speaker_name': 'André Heitor', 'text': 'E, pra ser sincero, é bem isso que eu sinto no SaaS.'}
# previous_speaker André Heitor
# sentence {'index': 493, 'speaker_name': 'André Heitor', 'text': 'Essa questão de é difícil você fazer alguma mudança, ter espaço, ter pista pra fazer isso.'}
# previous_speaker André Heitor
# sentence {'index': 494, 'speaker_name': 'André Heitor', 'text': 'E é uma coisa que eu sinto falta.'}
# previous_speaker André Heitor
# sentence {'index': 495, 'speaker_name': 'André Heitor', 'text': 'Até por isso que eu até falei que me tem interesse na Zub.'}
# previous_speaker André Heitor
# sentence {'index': 496, 'speaker_name': 'André Heitor', 'text': 'E aí você disse que você é o head, né?'}
# previous_speaker André Heitor
# sentence {'index': 497, 'speaker_name': 'André Heitor', 'text': 'de arquitetura.'}
# previous_speaker André Heitor
# sentence {'index': 498, 'speaker_name': 'André Heitor', 'text': 'Significa que você é o head de pré-vendas também de tudo ou não?'}
# previous_speaker André Heitor
# sentence {'index': 499, 'speaker_name': 'André Heitor', 'text': 'Isso.'}
# previous_speaker André Heitor
# sentence {'index': 500, 'speaker_name': 'Felipe Garcia', 'text': 'E cara, esse é um excelente ponto.'}
# previous_speaker André Heitor
# sentence {'index': 501, 'speaker_name': 'Felipe Garcia', 'text': 'A Amazon, eu acho que, falando da minha experiência no Google e na Microsoft, não posso falar como essas empresas estão.'}
# previous_speaker Felipe Garcia
# sentence {'index': 502, 'speaker_name': 'André Heitor', 'text': 'Hoje, mas.'}
# previous_speaker Felipe Garcia
# sentence {'index': 503, 'speaker_name': 'Felipe Garcia', 'text': 'Do tempo que eu trabalhei lá, a Amazon, para mim, ainda é referência nesse sentido.'}
# previous_speaker André Heitor
# sentence {'index': 504, 'speaker_name': 'Felipe Garcia', 'text': 'E vou falar por que a gente chama de arquitetura de soluções e não pré-vendas.'}
# previous_speaker Felipe Garcia
# sentence {'index': 505, 'speaker_name': 'Felipe Garcia', 'text': 'Porque é uma visão mais holística.'}
# previous_speaker Felipe Garcia
# sentence {'index': 506, 'speaker_name': 'Felipe Garcia', 'text': 'Cliente é cliente.'}
# previous_speaker Felipe Garcia
# sentence {'index': 507, 'speaker_name': 'Felipe Garcia', 'text': 'O time de vendas tem que estar lá na ponta, vendendo, ajudando o cliente a resolver problema.'}
# previous_speaker Felipe Garcia
# sentence {'index': 508, 'speaker_name': 'Felipe Garcia', 'text': 'Na verdade, não vendendo, a gente tem que estar lá na ponta, ajudando o cliente a resolver problema para que a gente consiga vender.'}
# previous_speaker Felipe Garcia
# sentence {'index': 509, 'speaker_name': 'Felipe Garcia', 'text': 'O objetivo não é vender, o objetivo é ajudar o cliente, a venda é a consequência.'}
# previous_speaker Felipe Garcia
# sentence {'index': 510, 'speaker_name': 'Felipe Garcia', 'text': 'Mas aí o que acontece?'}
# previous_speaker Felipe Garcia
# sentence {'index': 511, 'speaker_name': 'Felipe Garcia', 'text': 'Uma vez que você faz a venda ou pré-venda, missão cumprida.'}
# previous_speaker Felipe Garcia
# sentence {'index': 512, 'speaker_name': 'Felipe Garcia', 'text': 'Ema, ema, ema cada um com o seu problema.'}
# previous_speaker Felipe Garcia
# sentence {'index': 513, 'speaker_name': 'Felipe Garcia', 'text': 'O arquiteto holístico, ele é o cara que foi lá e por mais que a gente tenha Delivery e outros times trabalhando também no pós-implantação, a gente sabe que da mesma maneira os clientes, as demandas também mudam.'}
# previous_speaker Felipe Garcia
# sentence {'index': 514, 'speaker_name': 'Felipe Garcia', 'text': 'Então pode ser que a solução que foi desenhada há três meses atrás acabou de ser implantada seis meses depois, ela vai ter que fazer alguns ajustes ou alguma coisa foi planejada errado.'}
# previous_speaker Felipe Garcia
# sentence {'index': 515, 'speaker_name': 'Felipe Garcia', 'text': 'Isso volta para o arquiteto.'}
# previous_speaker Felipe Garcia
# sentence {'index': 516, 'speaker_name': 'Felipe Garcia', 'text': 'O arquiteto tem que acompanhar.'}
# previous_speaker Felipe Garcia
# sentence {'index': 517, 'speaker_name': 'Felipe Garcia', 'text': 'Então, o arquiteto tem esse papel híbrido de arquiteto, customer success manager, onde ele está lá junto com o vendedor garantindo o sucesso do cliente.'}
# previous_speaker Felipe Garcia
# sentence {'index': 518, 'speaker_name': 'Felipe Garcia', 'text': 'Então, essa é a visão que a gente dá aqui para o time, que é muito semelhante à visão de como a gente fazia na Amazon e eu considero como benchmark no mercado.'}
# previous_speaker Felipe Garcia
# sentence {'index': 519, 'speaker_name': 'André Heitor', 'text': 'Interessante.'}
# previous_speaker Felipe Garcia
# sentence {'index': 520, 'speaker_name': 'André Heitor', 'text': 'E...'}
# previous_speaker André Heitor
# sentence {'index': 521, 'speaker_name': 'André Heitor', 'text': 'Agora é uma questão.'}
# previous_speaker André Heitor
# sentence {'index': 522, 'speaker_name': 'André Heitor', 'text': 'Quanto que é ciclo de vendas?'}
# previous_speaker André Heitor
# sentence {'index': 523, 'speaker_name': 'André Heitor', 'text': 'Até para eu entender o negócio.'}
# previous_speaker André Heitor
# sentence {'index': 524, 'speaker_name': 'André Heitor', 'text': 'Qual é a complexidade das vendas de vocês?'}
# previous_speaker André Heitor
# sentence {'index': 525, 'speaker_name': 'André Heitor', 'text': 'Eu sei que são super complexas, né?'}
# previous_speaker André Heitor
# sentence {'index': 526, 'speaker_name': 'André Heitor', 'text': 'É que às vezes, dependendo da necessidade, você consegue fazer essa venda até rápido.'}
# previous_speaker André Heitor
# sentence {'index': 527, 'speaker_name': 'André Heitor', 'text': 'Porque acho que isso é interessante, também ter esse feeling.'}
# previous_speaker André Heitor
# sentence {'index': 528, 'speaker_name': 'Felipe Garcia', 'text': 'Tá.'}
# previous_speaker André Heitor
# sentence {'index': 529, 'speaker_name': 'Felipe Garcia', 'text': 'Excelente pergunta.'}
# previous_speaker Felipe Garcia
# sentence {'index': 530, 'speaker_name': 'Felipe Garcia', 'text': 'Cara, eu vou dizer que hoje é muito complexo por N razões.'}
# previous_speaker Felipe Garcia
# sentence {'index': 531, 'speaker_name': 'Felipe Garcia', 'text': 'E deixa eu quebrar aqui.'}
# previous_speaker Felipe Garcia
# sentence {'index': 532, 'speaker_name': 'Felipe Garcia', 'text': 'Nesse momento de transformação da Zup, ela está tentando se transformar de uma empresa que é mais vista como um body shop para ser vista como uma consultoria dev de desenvolvimento, AI first.'}
# previous_speaker Felipe Garcia
# sentence {'index': 533, 'speaker_name': 'Felipe Garcia', 'text': 'apoiada pelos nossos produtos, que é o Stack Spot, que vai lidar mais com uma venda consultiva, que está bem alinhado com Solution Selling, com Spin Selling.'}
# previous_speaker Felipe Garcia
# sentence {'index': 534, 'speaker_name': 'Felipe Garcia', 'text': 'E a gente vai mudar de um posicionamento de focar no sintoma para focar na causa raiz.'}
# previous_speaker Felipe Garcia
# sentence {'index': 535, 'speaker_name': 'Felipe Garcia', 'text': 'Para essas necessidades de Body Shop, eu diria que o ciclo é muito rápido.'}
# previous_speaker Felipe Garcia
# sentence {'index': 536, 'speaker_name': 'Felipe Garcia', 'text': 'Agora, para essa necessidade de consultoria first, é onde a gente está se reinventando e se reaprendendo.'}
# previous_speaker Felipe Garcia
# sentence {'index': 537, 'speaker_name': 'Felipe Garcia', 'text': 'E aí, cara, eu vou te dizer que o tempo médio aí de projeto, eu colocaria uns oito meses.'}
# previous_speaker Felipe Garcia
# sentence {'index': 538, 'speaker_name': 'André Heitor', 'text': 'Ah, Isabelle, para a venda complexa, E.'}
# previous_speaker Felipe Garcia
# sentence {'index': 539, 'speaker_name': 'Felipe Garcia', 'text': 'Eu vou te dizer assim, a venda não deveria ser complexa.'}
# previous_speaker André Heitor
# sentence {'index': 540, 'speaker_name': 'Felipe Garcia', 'text': 'Eu vou te dizer por que ela é complexa.'}
# previous_speaker Felipe Garcia
# sentence {'index': 541, 'speaker_name': 'Felipe Garcia', 'text': 'Por esses ajustes, hoje a gente está sem o Sales Ops.'}
# previous_speaker Felipe Garcia
# sentence {'index': 542, 'speaker_name': 'Felipe Garcia', 'text': 'A gente precisa repensar os processos, precisa adotar o seu esforço de maneira ampla, precisa treinar o time de arquitetura, precisa treinar o time de vendas, forecast é feito manualmente.'}
# previous_speaker Felipe Garcia
# sentence {'index': 543, 'speaker_name': 'Felipe Garcia', 'text': 'A gente não tem as informações dentro do CRM, tem muita coisa ainda que é feita em planilha, aí vai, volta, aí putz, o projeto já tá lá na frente, o cliente tá assinando, mas o jurídico não viu o contrato, opa, para tudo, volta pro jurídico, entendeu?'}
# previous_speaker Felipe Garcia
# sentence {'index': 544, 'speaker_name': 'Felipe Garcia', 'text': 'São coisas básicas de empresa que cresceu muito rápido e tem que se reinventar agora, que a gente tem que resolver.'}
# previous_speaker Felipe Garcia
# sentence {'index': 545, 'speaker_name': 'Felipe Garcia', 'text': 'Esses são os tipos de coisa que acabam tirando a celeridade de dias que deveriam ser rápidos.'}
# previous_speaker Felipe Garcia
# sentence {'index': 546, 'speaker_name': 'Felipe Garcia', 'text': 'Mas sim, concordo com você, se a gente fizer o mesmo trabalho de consultoria AI First, pegando um deal complexo, sim, só para você aprofundar, entender o cliente, desenhar uma solução, conseguir a aprovação dos departamentos, é algo que vai demorar.'}
# previous_speaker Felipe Garcia
# sentence {'index': 547, 'speaker_name': 'Felipe Garcia', 'text': 'Mas hoje, a maior parte dos deals que a gente tem pego, tem os deals complexos, mas eu vou dizer que na maior parte eles são demorados muito mais por essa falta de definição de processo.'}
# previous_speaker Felipe Garcia
# sentence {'index': 548, 'speaker_name': 'Felipe Garcia', 'text': 'Tudo exige reunião.'}
# previous_speaker Felipe Garcia
# sentence {'index': 549, 'speaker_name': 'Felipe Garcia', 'text': 'E a gente tem às vezes até repetido o mesmo desafio, tá acontecendo pela quarta vez e a gente tá fazendo os mesmos processos da primeira vez, que é reunião.'}
# previous_speaker Felipe Garcia
# sentence {'index': 550, 'speaker_name': 'Felipe Garcia', 'text': 'Porque o pessoal tá tão focado na execução, que não tem aquele momento de parar, que nem você falou no momento, deixa eu analisar os dias que eu perdi, porque que eu tô perdendo, a gente não fez isso até hoje.'}
# previous_speaker Felipe Garcia
# sentence {'index': 551, 'speaker_name': 'Felipe Garcia', 'text': 'Porque existe a vontade, mas não tem ninguém olhando de fato para seus ops para pegar o boi pelo chifre e começar a colocar ordem na casa, entendeu?'}
# previous_speaker Felipe Garcia
# sentence {'index': 552, 'speaker_name': 'Felipe Garcia', 'text': 'Vendedor, cara, você não atualizou os seus forces, não atualizou os seus forces, você não faz forecast, volta para casa e faz a lição de casa, depois você volta aqui, né?'}
# previous_speaker Felipe Garcia
# sentence {'index': 553, 'speaker_name': 'Felipe Garcia', 'text': 'Enfim, acho que essa é a minha resposta para a sua questão, sua pergunta de tempo médio aí, de fechamento.'}
# previous_speaker Felipe Garcia
# sentence {'index': 554, 'speaker_name': 'André Heitor', 'text': 'Acho que é isso, né?'}
# previous_speaker Felipe Garcia
# sentence {'index': 555, 'speaker_name': 'André Heitor', 'text': 'Também não quero prender você.'}
# previous_speaker André Heitor
# sentence {'index': 556, 'speaker_name': 'André Heitor', 'text': 'Acho que foi o tempo.'}
# previous_speaker André Heitor
# sentence {'index': 557, 'speaker_name': 'Felipe Garcia', 'text': 'Foi o tempo.'}
# previous_speaker André Heitor
# sentence {'index': 558, 'speaker_name': 'Felipe Garcia', 'text': 'Cara, muito obrigado por tudo, pela experiência e pelo apoio em ajudar a reagendar a entrevista.'}
# previous_speaker Felipe Garcia
# sentence {'index': 559, 'speaker_name': 'Felipe Garcia', 'text': 'Eu vou colocar o feedback no sistema agora.'}
# previous_speaker Felipe Garcia
# sentence {'index': 560, 'speaker_name': 'Felipe Garcia', 'text': 'A Camila ou a Késia, não sei, as duas são o seu ponto de contato e elas vão te manter informado sobre as próximas etapas no processo.'}
# previous_speaker Felipe Garcia
# sentence {'index': 561, 'speaker_name': 'Felipe Garcia', 'text': 'Te adicionei no LinkedIn, cara, você tem meu contato.'}
# previous_speaker Felipe Garcia
# sentence {'index': 562, 'speaker_name': 'Felipe Garcia', 'text': 'Qualquer outra dúvida, curiosidade que você tiver, cara, fica à vontade para me chamar ou por e-mail ou no LinkedIn.'}
# previous_speaker Felipe Garcia
# sentence {'index': 563, 'speaker_name': 'Felipe Garcia', 'text': 'Aí eu vou tentar te responder e se eu não tiver resposta, eu vou te conectar com quem sabe, tá bom?'}
# previous_speaker Felipe Garcia
# sentence {'index': 564, 'speaker_name': 'André Heitor', 'text': 'Perfeito.'}
# previous_speaker Felipe Garcia
# sentence {'index': 565, 'speaker_name': 'André Heitor', 'text': 'Eu também queria agradecer, Filipe, até por ter dado esse espaço na volta de férias, eu sei que...'}
# previous_speaker André Heitor
# sentence {'index': 566, 'speaker_name': 'André Heitor', 'text': 'volta de férias é sempre uma época maluca, né?'}
# previous_speaker André Heitor
# sentence {'index': 567, 'speaker_name': 'André Heitor', 'text': 'Então você ter se parado uma hora para conversar comigo também eu agradeço.'}
# previous_speaker André Heitor
# sentence {'index': 568, 'speaker_name': 'Felipe Garcia', 'text': 'Eu que agradeço, é muito importante, cara.'}
# previous_speaker André Heitor
# sentence {'index': 569, 'speaker_name': 'Felipe Garcia', 'text': 'A gente precisa de muito, muito, muito alguém nessa posição de ser os ops.'}
# previous_speaker Felipe Garcia
# sentence {'index': 570, 'speaker_name': 'Felipe Garcia', 'text': 'Brigadão, desejo muita sorte para você na entrevista e espero que dê tudo certo aí, tá bom?'}
# previous_speaker Felipe Garcia
# sentence {'index': 571, 'speaker_name': 'André Heitor', 'text': 'Beleza, obrigado, Felipe.'}
# previous_speaker Felipe Garcia
# sentence {'index': 572, 'speaker_name': 'Felipe Garcia', 'text': 'Abraço, tchau, tchau.'}
# previous_speaker André Heitor
# PDF salvo no S3 vlr1U3rEX0zd6MQq.pdf
